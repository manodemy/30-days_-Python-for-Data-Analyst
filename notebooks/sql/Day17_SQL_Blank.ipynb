-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: Data Modelling & Analytics Engineering
-- Design dimensional schemas, build analytical models, and maintain version control.
--
-- ### 📋 Database Source: `ecommerce.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. Dimensional Modeling : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">Star Schema, dbt, and SCDs</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     Data modeling structures databases for reporting. Star schemas consist of central fact tables (transactions) joined to dimension tables (context). Slowly Changing Dimensions (SCD Type 1 overwrites, SCD Type 2 adds history rows) track attributes. Analytics engineering tools (like dbt) organize query pipelines.
-- </div>

-- %%
SELECT o.id, c.name, o.order_date, o.total_amount FROM orders o JOIN customers c ON o.customer_id = c.id;

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>Modelling</code></b>
-- </h3>

-- %% [markdown]
-- ### Identify the fact tables and dimension tables in the ecommerce database.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Explain grain definition: what does a single row in order_items represent?

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Explain the difference between a surrogate key and a natural key.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Explain what a Slowly Changing Dimension (SCD) Type 2 is and how it tracks history.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Explain the staging, intermediate, and mart layers in dbt projects.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (Schema Design):** List the foreign key relationships linking products, orders, and order_items.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### Explain the difference between a Star Schema and a Snowflake Schema. Which is better for query performance and why?

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### How does dbt model references work? Explain the difference between ref() and source() functions.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 17 Executive Summary
--
-- Data modeling maps real-world processes. Star schemas optimize query performance, while analytics engineering structures SQL scripts for clean data pipelines.
--
--
-- **Next Up: SQL Day 18**
