-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: Date & Time Functions
-- Perform temporal arithmetic, extract year/month components, and filter records by dates.
--
-- ### 📋 Database Source: `ecommerce.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. Date Manipulation : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">Formatting and Intervals</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     SQLite stores dates as text (ISO 8601 strings), reals, or integers. STRFTIME formats and extracts date parts: %Y (year), %m (month), %d (day), %w (day of week: 0=Sunday). Julian date difference is calculated using JULIANDAY(). Other dialects support DATEADD, DATEDIFF, or DATE_TRUNC.
-- </div>

-- %%
SELECT id, order_date, STRFTIME('%Y', order_date) as year, STRFTIME('%m', order_date) as month FROM orders WHERE order_date >= '2022-01-01';

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>Date Formatting</code></b>
-- </h3>

-- %% [markdown]
-- ### Find all orders placed in the year 2022.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Find all orders placed in the month of October.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Find orders placed on weekends (where STRFTIME '%w' is '0' or '6').

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Calculate the number of days between customer signup date and their first order date using <code>JULIANDAY</code>.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### List all customers who signed up in the final quarter (Q4) of 2022.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (Signup Intervals):** Calculate the average time in days between signup date and order date for all orders.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### Write a query to calculate the number of orders placed in each month of 2022.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### How would you handle timezone offsets in standard SQL? Explain the role of AT TIME ZONE.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 10 Executive Summary
--
-- Date calculations are crucial for cohort analyses and dashboards. Master formatting functions (STRFTIME in SQLite) and date differences to parse temporal records.
--
--
-- **Next Up: SQL Day 11**
