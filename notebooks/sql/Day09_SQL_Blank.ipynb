-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: Window Functions II — Analytics & Frames
-- Calculate running aggregates, moving averages, and offset values (LAG/LEAD) for trend analysis.
--
-- ### 📋 Database Source: `ecommerce.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. Analytic Window Functions : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">LAG, LEAD, Running Totals</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     Analytic window functions analyze data flows. LAG and LEAD look back or forward by an offset. Adding an ORDER BY clause inside OVER() calculates running totals. Frame specifications (like ROWS BETWEEN) allow calculating moving averages over rolling windows.
-- </div>

-- %%
SELECT id, order_id, qty, SUM(qty) OVER (ORDER BY id) as running_qty FROM order_items;

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>Offsets & Frames</code></b>
-- </h3>

-- %% [markdown]
-- ### Use <code>LAG()</code> to display the signup date of the previous customer registered on the system.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Use <code>LEAD()</code> to display the signup date of the next customer registered on the system.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Calculate the running sum of orders total_amount ordered by order_date.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Use <code>FIRST_VALUE()</code> to display the first product ordered by each customer.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Calculate a 3-order moving average of product costs using <code>ROWS BETWEEN 2 PRECEDING AND CURRENT ROW</code>.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (Cumulative Spend):** Calculate a running total of order amounts grouped by customer, ordered by order date.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### Write a query to calculate month-over-month growth of order totals. Use the LAG window function to compare current month with previous.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### How do you specify a frame window in SQL? Explain the difference between 'ROWS' and 'RANGE'.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 9 Executive Summary
--
-- Offset functions (LAG/LEAD) make comparative timeline reports simple. Running aggregates and frame parameters give you control over cumulative statistics.
--
--
-- **Next Up: SQL Day 10**
