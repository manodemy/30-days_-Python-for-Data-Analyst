-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: String & Type Functions
-- Clean text strings and explicitly convert column data types.
--
-- ### 📋 Database Source: `ecommerce.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. Text Manipulation & Casts : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">String operations and Explicit Casting</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     Text functions modify strings: UPPER, LOWER, TRIM (removes whitespace), REPLACE, and SUBSTR. Explicit conversions are handled via CAST(expression AS type). COALESCE handles fallback values for missing records, and NULLIF returns NULL if parameters are equal.
-- </div>

-- %%
SELECT TRIM(name) as clean_name, LOWER(email) as clean_email, CAST(cost_price AS INTEGER) as price_int FROM products JOIN categories ON products.category_id = categories.id LIMIT 5;

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>String Cleanup</code></b>
-- </h3>

-- %% [markdown]
-- ### Convert all customer names to uppercase and emails to lowercase.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Trim extra spaces from customer names and replace the domain '@gmail.com' with '@googlemail.com'.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Extract the first 3 characters of each customer's region using <code>SUBSTR</code>.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Find the character position of '@' in each customer's email using <code>INSTR</code>.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Convert product cost prices to integers using <code>CAST</code>.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (Domain Extraction):** Write a query to extract the domain extension (everything after the '@' symbol) from customer emails.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### Write a query to extract the username part of an email address (everything before the '@' symbol).

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### Explain implicit vs explicit type coercion and the risks of dividing integers without casting to floats.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 11 Executive Summary
--
-- Data cleaning is 80% of an analyst's work. Master string functions to clean text cells, and use CAST to convert types for safe mathematical checks.
--
--
-- **Next Up: SQL Day 12**
