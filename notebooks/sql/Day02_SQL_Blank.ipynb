-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: SELECT & Filtering — Retrieving Rows
-- Filter query results using conditional clauses, logical operators, and value constraints.
--
-- ### 📋 Database Source: `retail.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. The WHERE Clause : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">Filtering Rows with Constraints</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     The WHERE clause filters rows based on logical conditions. Standard comparison operators (=, !=, <, >, <=, >=) can be combined using logical operators (AND, OR, NOT). Operator precedence can be adjusted using parentheses. BETWEEN filters within a range (inclusive), and IN filters against a list of specific values.
-- </div>

-- %%
SELECT * FROM sales WHERE region = 'North' AND amount > 5000;

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>WHERE Filters</code></b>
-- </h3>

-- %% [markdown]
-- ### Find all sales transactions where the <code>category</code> is 'Electronics'.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Find all sales where the <code>amount</code> is between 3000 and 7000 (inclusive) using <code>BETWEEN</code>.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Find all products in the <code>products</code> table where <code>unit_price</code> is less than 1500.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Retrieve all sales transactions in either the 'South' or 'West' regions using <code>IN</code>.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Retrieve all sales transactions that are NOT in the 'North' region.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (High Value Transactions):** Retrieve all sales transactions over ₹8,000 in the 'East' region.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### Write a query to select all products from the products table where the unit price is greater than 5000 and the stock quantity is less than 30.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### Explain SQL execution order: why does the WHERE clause execute before the SELECT clause?

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 2 Executive Summary
--
-- Filtering is the core of database analysis. Using WHERE with comparisons, lists (IN), ranges (BETWEEN), and logical operators lets you isolate exact cohorts of records.
--
--
-- **Next Up: SQL Day 3**
