-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: Query Optimisation & Execution Plans
-- Inspect query execution plans, configure indexes, and optimize query structure.
--
-- ### 📋 Database Source: `ecommerce.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. Query Optimization : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">Explain Query Plan & Indexes</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     Optimization speeds up database operations. EXPLAIN QUERY PLAN shows how the database engine runs a query, identifying full table scans (SCAN TABLE) and index lookups (SEARCH TABLE). Optimization involves index management, avoiding functions on index columns in WHERE, and filtering early.
-- </div>

-- %%
EXPLAIN QUERY PLAN SELECT * FROM customers WHERE id = 5;

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>Explain Plans</code></b>
-- </h3>

-- %% [markdown]
-- ### Run an <code>EXPLAIN QUERY PLAN</code> on a query that joins orders and customers.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Run <code>EXPLAIN QUERY PLAN</code> on a query searching customer names by a LIKE pattern (<code>%name%</code>).

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Explain why standard indexes are bypassed when searching using a function (e.g. <code>WHERE UPPER(name) = 'AMIT'</code>).

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Explain what a covering index is and why it avoids table lookups.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Explain the difference between a clustered and a non-clustered index.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (Index Analysis):** Run EXPLAIN QUERY PLAN on a query joining orders and order_items on order_id to verify if it uses indexes.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### What is a database index? Under what conditions can an index slow down database operations?

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### What is a full table scan? How do you avoid it in a production database?

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 14 Executive Summary
--
-- Optimization is key to production database administration. Master explain plans to identify bottleneck table scans, and use indexes to speed up lookups.
--
--
-- **Next Up: SQL Day 15**
