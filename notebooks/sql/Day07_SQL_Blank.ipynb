-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: Common Table Expressions (CTEs)
-- Define temporary, named result sets to write cleaner, modular, and readable queries.
--
-- ### 📋 Database Source: `ecommerce.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. Common Table Expressions : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">WITH Clause and CTEs</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     CTEs define temporary, named result sets that exist only during query execution. Chaining multiple CTEs allows building modular logic. Recursive CTEs consist of an anchor member unioned with a recursive member, which is useful for hierarchical traversals (like organizational charts).
-- </div>

-- %%
WITH SalesByCustomer AS (
    SELECT customer_id, SUM(total_amount) as total_spent
    FROM orders GROUP BY customer_id
)
SELECT c.name, s.total_spent FROM SalesByCustomer s JOIN customers c ON s.customer_id = c.id WHERE s.total_spent > 15000;

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>CTE Fundamentals</code></b>
-- </h3>

-- %% [markdown]
-- ### Write a CTE named <code>CustomerCount</code> that counts orders per customer, and select all columns from it.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Use a CTE to calculate the average cost price of products in each category, then select categories with averages above 5000.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Write a query utilizing two chained CTEs: the first getting product details, the second calculating category totals.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Use a CTE to find customers who signed up in 2022 and have placed more than 2 orders.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Rewrite a subquery filtering products above average cost price into a query using a CTE.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (Spender Revenue):** Write a CTE to get total revenue per product category, then join with categories to show names.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### What is a recursive CTE? Write a conceptual recursive CTE to generate numbers from 1 to 10.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### Compare CTEs vs Subqueries vs Temporary Tables. When should you use each in a production environment?

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 7 Executive Summary
--
-- CTEs transform complex, nested SQL scripts into readable, step-by-step logic. Chaining CTEs with WITH modularizes your queries, improving maintenance and debugging.
--
--
-- **Next Up: SQL Day 8**
