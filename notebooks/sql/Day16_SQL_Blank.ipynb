-- %% [markdown]
-- ---
-- ## 🎯 Enterprise Objective: Advanced Analytics Patterns
-- Build analytical reporting pipelines: cohorts, funnels, retention, and customer scoring (RFM).
--
-- ### 📋 Database Source: `ecommerce.db`
--
-- Every cell in this notebook runs against this database on the server.

-- %% [markdown]
-- <h2 style="color: #000000ff; background-color: #02fff2ff; border-left: 6px solid #0c0c0cff; padding: 12px 15px; margin-top: 40px; border-radius: 4px;">
--     <b>1. Cohort & Funnel Analysis : <span style="color: #070707ff; font-size: 0.85em; font-weight: normal;">Advanced Analytic SQL Patterns</span></b>
-- </h2>
--
-- <div style="border-left: 4px solid #4DB6AC; padding-left: 15px; margin: 15px 0; color: #CCCCCC;">
--     <b>🔍 Concept</b><br>
--     Analytical patterns trace client lifecycles. Cohort analysis groups users by sign-up month and measures activity over time. Funnel analysis tracks drop-offs across sequence stages. RFM scoring (Recency, Frequency, Monetary) groups customers into segments using window functions like NTILE.
-- </div>

-- %%
SELECT customer_id, COUNT(*) as frequency, SUM(total_amount) as monetary FROM orders GROUP BY customer_id;

-- %% [markdown]
-- <h3 style="color: #C7D2FE; background-color: #0e0e0fff; border-left: 6px solid #6366F1; padding: 12px 15px; margin-top: 50px; margin-bottom: 20px; border-radius: 4px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
--     <b>🧪 Concept Checks: <code>Analytics Patterns</code></b>
-- </h3>

-- %% [markdown]
-- ### Group customers by signup month to count cohorts.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Count orders per customer and classify them using NTILE into 5 spend brackets.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Write a query calculating the time-to-convert between signup date and first order date.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Calculate customer retention: count customers who ordered in 2022 and ordered in 2023.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ### Write a query to find the customer churn: active in 2022 but inactive in 2023.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 🛠️ Professional Practice Tasks
-- Write SQL queries to solve the following tasks.

-- %% [markdown]
-- ### **Task 1 (RFM Brackets):** Write a query to bucket customers into 3 tiers based on their monetary value using NTILE.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 💻 Pure Coding Interview Questions

-- %% [markdown]
-- ---
-- ## Q1.
-- ### Write a query to calculate customer cohort retention: find the percentage of customers signing up in a month who purchase again in the following month.

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- ## Q2.
-- ### Describe how you would model customer lifecycle funnel stages in SQL. What joins or aggregation are required?

-- %%
-- Write your SQL query here

-- %% [markdown]
-- ---
-- # 📊 Day 16 Executive Summary
--
-- Cohorts, funnels, and RFM metrics are vital business logic. Master conditional counts and window groupings to build dashboard reporting pipelines.
--
--
-- **Next Up: SQL Day 17**
